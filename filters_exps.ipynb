# %%
# import key libraries
from PIL import Image, ImageDraw, ImageFont
import torch, torchvision
import numpy as np
from matplotlib import cm
import matplotlib.pyplot as plt

import utils.filters as filters

path = 'sample_pics/idris.jpg'
pic = Image.open(path)

# %% [markdown]
# # Different filters, illustrated below
#
# pixelation, contour, emboss, edge detection
#
# ## pixelation

# %%
pixelated = filters.pixelate(pic)
pixelated
# Out:
# <PIL.Image.Image image mode=RGB size=1000x562 at 0x7F89CD68FAC8>

# %%
contoured = filters.contour(pic)
contoured
# Out:
# <PIL.Image.Image image mode=RGB size=1000x562 at 0x7F89CD68F7F0>

# %%
embossed = filters.emboss(pic)
embossed
# Out:
# <PIL.Image.Image image mode=RGB size=1000x562 at 0x7F8925D5CBE0>

# %%
edged = filters.edges(pic)
edged
# Out:
# <PIL.Image.Image image mode=RGB size=1000x562 at 0x7F89CDF5BEB8>
